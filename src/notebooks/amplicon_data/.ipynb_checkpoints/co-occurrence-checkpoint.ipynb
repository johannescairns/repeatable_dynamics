# %% [markdown]
# # Species co-occurrence analysis
#
# #### Source: https://cran.r-project.org/web/packages/netassoc/netassoc.pdf

# %%
# Housekeeping

library(netassoc)

# %%
# Read in data

species_composition = read.table("../../../data/amplicon/species_composition_normalized_to_15k_reads.txt", 
                                 sep = "\t",
                                 header = T,
                                 row.names = 1)

metadata = read.table("../../../data/amplicon/metadata.txt",
                      sep = "\t",
                      header = T,
                      row.names = 1)


# Extract regime shift data without predation

x = metadata$Experiment != "FiltrateExp" & # keep only regime shift data
    metadata$Predation != 1 & # exclude predation
    metadata$Immigration != "stock" # exclude stock

# Subset

species_composition = species_composition[x,] # keep only species with data
species_composition = species_composition[,colSums(species_composition)>0]
metadata = metadata[x,-c(3, 6)] # remove redundant columns
# metadata$ID = paste(metadata$Streptomycin, metadata$Immigration, metadata$Replicate, sep = "_")
# metadata$ID = as.factor(metadata$ID)
#species_composition$SAMPLE = rownames(species_composition)
#metadata$SAMPLE = rownames(metadata)

head(species_composition)
# Out:
#         Aeromonas_caviae_HAMBI_1972 Agrobacterium_tumefaciens_HAMBI_105
# T12_0_1 5766                         3
# T4_0_1  3889                        81
# T8_0_1  5054                        21
# T12_0_2 6674                         5
# T4_0_2  4478                        73
# T8_0_2  4558                        60
#         Azorhizobium_caulinodans_HAMBI_216 Azospirillum_brasilense_HAMBI_3172
# T12_0_1 0                                   3
# T4_0_1  0                                   9
# T8_0_1  0                                  28
# T12_0_2 0                                  14
# T4_0_2  0                                   9
# T8_0_2  0                                  17
#         Bordetella_avium_HAMBI_2160 Citrobacter_koseri_HAMBI_1287
# T12_0_1 28                           201
# T4_0_1  45                          3754
# T8_0_1  14                           868
# T12_0_2  5                           359
# T4_0_2  46                          3315
# ...

# %%
M1 = make_netassoc_network(t(species_composition))
# Out:
# Plot with title “Observed sp x site”
# Calculating observed co-occurrence scores...
# Generating null replicate 1...
# Generating null replicate 2...
# Generating null replicate 3...
# Generating null replicate 4...
# Generating null replicate 5...
# Generating null replicate 6...
# Generating null replicate 7...
# Generating null replicate 8...
# Generating null replicate 9...
# Generating null replicate 10...
# Generating null replicate 11...
# Generating null replicate 12...
# Generating null replicate 13...
# Generating null replicate 14...
# Generating null replicate 15...
# Generating null replicate 16...
# Generating null replicate 17...
# Generating null replicate 18...
# Generating null replicate 19...
# Generating null replicate 20...
# Generating null replicate 21...
# Generating null replicate 22...
# Generating null replicate 23...
# Generating null replicate 24...
# Generating null replicate 25...
# Generating null replicate 26...
# Generating null replicate 27...
# ...

# %%
plot_netassoc_network(M1$network_all)
# Out:
# Plot with title “”

# %%
M1
# Out:
# $matrix_spsite_obs
#                                           T12_0_1 T4_0_1 T8_0_1 T12_0_2 T4_0_2
# Aeromonas_caviae_HAMBI_1972                  5766   3889   5054    6674   4478
# Agrobacterium_tumefaciens_HAMBI_105             3     81     21       5     73
# Azorhizobium_caulinodans_HAMBI_216              0      0      0       0      0
# Azospirillum_brasilense_HAMBI_3172              3      9     28      14      9
# Bordetella_avium_HAMBI_2160                    28     45     14       5     46
# Citrobacter_koseri_HAMBI_1287                 201   3754    868     359   3315
# Comamonas_testosteroni_HAMBI_403              111      0      7       0      0
# Cupriavidus_necator_HAMBI_2164                  0      0      0       0      0
# Elizabethkingia_meningoseptica_HAMBI_1875    1182   2939   4391    2209   3104
# Escherichia_coli_JE2571_RP4                     0      0      0       0      0
# Hafnia_alvei_HAMBI_1279                         0     72      0       0      0
# ...
