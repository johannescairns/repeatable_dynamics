# %% [markdown]
# # Analyses and figures for total derived alleles for genes with multiple nonsynonymous hits

# %%
# Housekeeping

library(ggplot2)
library(MASS)
library(nlme)
library(scales)
source("source.R")

# %%
# Read in data

variants = read.table("../../data/deep_seq/multihit_nonsynonymous_variant_data.txt", 
                      sep = "\t", 
                      header = T)

# %%
# Aggregate by species per sample

counts = aggregate(VARIANT_FREQUENCY ~ SPECIES-TIME-ANTIBIOTIC-IMMIGRATION-REPLICATE-AMPLICON_READS, 
                      data = variants, FUN = function(x){sum(x)})

counts = counts[counts$VARIANT_FREQUENCY != 0,] # remove potential 0 count rows
head(counts)
# Out:
#   SPECIES    TIME ANTIBIOTIC IMMIGRATION REPLICATE AMPLICON_READS
# 1 HAMBI_2443  8     4        0           1         0
# 2 HAMBI_1896  8   128        0           1         0
# 3 HAMBI_2443  8     4        0           2         0
# 4 HAMBI_2659  8    16        0           2         0
# 5 HAMBI_2659 12    16        0           2         0
# 6 HAMBI_1896  8   128        0           2         0
#   VARIANT_FREQUENCY
# 1 0.8333333
# 2 3.0000000
# 3 0.5000000
# 4 1.0000000
# 5 1.0000000
# 6 1.0000000

# %%
# Convert amplicon reads (normalized to 15,000 reads) to relative abundance

counts$REL_ABUNDANCE = counts$AMPLICON_READS/15000

# Log transform (convert zero abundance to extremely low value to prevent downstream problems)

counts$LOG_REL_ABUNDANCE = log10(ifelse(counts$REL_ABUNDANCE == 0,
                              0.0000000000001,
                              counts$REL_ABUNDANCE))
head(counts)
# Out:
#   SPECIES    TIME ANTIBIOTIC IMMIGRATION REPLICATE AMPLICON_READS
# 1 HAMBI_2443  8     4        0           1         0
# 2 HAMBI_1896  8   128        0           1         0
# 3 HAMBI_2443  8     4        0           2         0
# 4 HAMBI_2659  8    16        0           2         0
# 5 HAMBI_2659 12    16        0           2         0
# 6 HAMBI_1896  8   128        0           2         0
#   VARIANT_FREQUENCY REL_ABUNDANCE LOG_REL_ABUNDANCE
# 1 0.8333333         0             -13
# 2 3.0000000         0             -13
# 3 0.5000000         0             -13
# 4 1.0000000         0             -13
# 5 1.0000000         0             -13
# 6 1.0000000         0             -13

# %%
# Reformat

counts$SAMPLE = paste(counts$ANTIBIOTIC, 
                      counts$IMMIGRATION, 
                      counts$REPLICATE,
                      sep = "_")

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Data exploration

# %%
# Balance of categorical covariates

x = as.data.frame(table(counts$SPECIES))
x

# Let's remove species with less than 20 observations

y = x[x$Freq >= 20,]
y
counts2 = counts[counts$SPECIES %in% y$Var1,]

table(counts2$ANTIBIOTIC) # ok
table(counts2$IMMIGRATION) # ok
# Out:
#    Var1       Freq
# 1  HAMBI_105  30
# 2  HAMBI_1287  8
# 3  HAMBI_1874 10
# 4  HAMBI_1896 46
# 5  HAMBI_1972 37
# 6  HAMBI_1977 38
# 7  HAMBI_1992  0
# 8  HAMBI_2160  4
# 9  HAMBI_2443  6
# 10 HAMBI_2659 12
# 11 HAMBI_3031 13
# 12 HAMBI_3172 24
#    Var1       Freq
# 1  HAMBI_105  30
# 4  HAMBI_1896 46
# 5  HAMBI_1972 37
# 6  HAMBI_1977 38
# 12 HAMBI_3172 24
#   0   4  16 128
#  48  44  48  35
#  0  1
# 92 83

# %% [markdown]
# ## Model specification

# %%
# Let's use generalized least squares models that account for repeated measures

# Define basic model

M1 = gls(VARIANT_FREQUENCY ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME + LOG_REL_ABUNDANCE, 
         data = counts2, 
         correlation = corAR1(form = ~ 1 | SAMPLE),
         method = "ML")

# Find best model based on AIC

M2 = stepAIC(M1, 
             scope = list(upper = ~SPECIES*ANTIBIOTIC*IMMIGRATION*TIME*LOG_REL_ABUNDANCE, lower = ~1), 
             trace = FALSE)

# %%
# Let's also try with species specific variance structure

M3 = gls(VARIANT_FREQUENCY ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME + LOG_REL_ABUNDANCE, 
         data = counts2, 
         weights = varIdent(form = ~1 | SPECIES),
         correlation = corAR1(form = ~ 1 | SAMPLE),
         method = "ML")
M4 = stepAIC(M3, 
             scope = list(upper = ~SPECIES*ANTIBIOTIC*IMMIGRATION*TIME*LOG_REL_ABUNDANCE, lower = ~1), 
             trace = FALSE)

# %%
# Let's compare models with and without species specific variance structure

anova(M2, M4) # M4 better
# Out:
#    call
# M2 gls(model = VARIANT_FREQUENCY ~ SPECIES + ANTIBIOTIC + IMMIGRATION +     SPECIES:ANTIBIOTIC + SPECIES:IMMIGRATION + ANTIBIOTIC:IMMIGRATION +     SPECIES:ANTIBIOTIC:IMMIGRATION, data = counts2, correlation = corAR1(form = ~1 |     SAMPLE), method = "ML")
# M4 gls(model = VARIANT_FREQUENCY ~ SPECIES + ANTIBIOTIC + IMMIGRATION +     SPECIES:ANTIBIOTIC + SPECIES:IMMIGRATION + ANTIBIOTIC:IMMIGRATION +     SPECIES:ANTIBIOTIC:IMMIGRATION, data = counts2, correlation = corAR1(form = ~1 |     SAMPLE), weights = varIdent(form = ~1 | SPECIES), method = "ML")
#    Model df AIC      BIC      logLik    Test   L.Ratio  p-value
# M2 1     22 654.8250 724.4503 -305.4125              NA           NA
# M4 2     26 588.1024 670.3868 -268.0512 1 vs 2 74.72264 2.280749e-15

# %% [markdown]
# ## Model validation

# %%
# Homogeneity: residuals vs. predicted values

E1 = resid(M4)
F1 = fitted(M4)
par(mfrow = c(1, 1))
plot(x = F1, 
     y = E1, 
     xlab = "Fitted values",
     ylab = "Residuals")
abline(v = 0, lwd = 2, col = 2)
abline(h = 0, lty = 2, col = 1)
# Out:
# plot without title

# %%
# Homogeneity/independence: residuals vs. covariates

plot( x = counts2$SPECIES,
      y = E1,
      xlab = "Species",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$ANTIBIOTIC,
      y = E1,
      xlab = "Antibiotic",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$IMMIGRATION,
      y = E1,
      xlab = "Immigration",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$LOG_REL_ABUNDANCE,
      y = E1,
      xlab = "Relative abundance",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$TIME,
      y = E1,
      xlab = "Time",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# Normality

par(mfrow = c(1, 1))
hist(E1, breaks = 10) # ok
# Out:
# Plot with title “Histogram of E1”

# %% [markdown]
# ## Model inspection

# %%
# Model validation plots look ok, let's go with M4

anova(M4)

# species and antibiotic explain total derived allele frequency
# also many interactions, the biggest being between species and antibiotic
# Out:
#                                numDF F-value    p-value
# (Intercept)                    1     249.802148 3.968131e-34
# SPECIES                        4      85.106570 4.209751e-38
# ANTIBIOTIC                     1      33.267755 4.226319e-08
# IMMIGRATION                    1       1.585668 2.098391e-01
# SPECIES:ANTIBIOTIC             4      26.207788 1.321022e-16
# SPECIES:IMMIGRATION            4       8.877863 1.760516e-06
# ANTIBIOTIC:IMMIGRATION         1      10.417343 1.523549e-03
# SPECIES:ANTIBIOTIC:IMMIGRATION 4      11.196643 5.260258e-08

# %%
# Species effect

counts$SPECIES = as.factor(as.character(counts$SPECIES))

ggplot(counts, aes(SPECIES, VARIANT_FREQUENCY)) +
    geom_boxplot() +
    ylab("Total derived frequency of nonsynonymous mutations in multi-hit genes") +
    coord_flip() +
    scale_x_discrete(limits = rev(levels(counts$SPECIES))) +
    theme(axis.title.y = element_blank())

ggsave("../../manuscript/figures/total_derived_analyses_multihit_variants_species.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
# Antibiotic by species effect

ggplot(counts[counts$SPECIES != "HAMBI_2160" & counts$SPECIES != "HAMBI_2443",], # remove these to avoid empty facets
    aes(ANTIBIOTIC, VARIANT_FREQUENCY)) +
    geom_smooth(method = "glm", method.args = list(family = "Gamma"), colour="red")+
    ylab("Total derived frequency of nonsynonymous mutations in multi-hit genes") +
    xlab(expression(paste("Streptomycin concentration ", (mu*g*' mL'^-1)))) +
    facet_grid(~SPECIES, space = "free") +
    scale_x_continuous(breaks = c(0, 128))

ggsave("../../manuscript/figures/total_derived_analyses_multihit_variants_antibiotic_by_species.pdf", width = 12)
# Out:
# Saving 12 x 7 in image
# plot without title
