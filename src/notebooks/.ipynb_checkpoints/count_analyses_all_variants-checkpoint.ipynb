# %% [markdown]
# # Analyses and figures for total variant count for filtered variants

# %%
# Housekeeping

library(ggplot2)
library(MASS)
library(nlme)
library(scales)
source("source.R")

# %%
# Read in data

variants = read.table("../../data/deep_seq/filtered_variant_data.txt", 
                      sep = "\t", 
                      header = T)

# %%
# Convert frequency to count data

variants$COUNT = ifelse(variants$VARIANT_FREQUENCY == 0, 0, 1)

# %%
# Aggregate by species per sample

counts = aggregate(COUNT ~ SPECIES-TIME-ANTIBIOTIC-IMMIGRATION-REPLICATE-AMPLICON_READS, 
                      data = variants, FUN = function(x){sum(x)})

counts = counts[counts$COUNT != 0,] # remove potential 0 count rows
head(counts)
# Out:
#   SPECIES    TIME ANTIBIOTIC IMMIGRATION REPLICATE AMPLICON_READS COUNT
# 1 HAMBI_2443  8     4        0           1         0              10
# 2 HAMBI_2160  8    16        0           1         0               2
# 3 HAMBI_1896  8   128        0           1         0              11
# 4 HAMBI_2659  8    16        1           1         0               1
# 5 HAMBI_3172  8    16        1           1         0               1
# 6 HAMBI_2659 12    16        1           1         0               1

# %%
# Convert amplicon reads (normalized to 15,000 reads) to relative abundance

counts$REL_ABUNDANCE = counts$AMPLICON_READS/15000

# Log transform (convert zero abundance to extremely low value to prevent downstream problems)

counts$LOG_REL_ABUNDANCE = log10(ifelse(counts$REL_ABUNDANCE == 0,
                              0.0000000000001,
                              counts$REL_ABUNDANCE))
head(counts)
# Out:
#   SPECIES    TIME ANTIBIOTIC IMMIGRATION REPLICATE AMPLICON_READS COUNT
# 1 HAMBI_2443  8     4        0           1         0              10
# 2 HAMBI_2160  8    16        0           1         0               2
# 3 HAMBI_1896  8   128        0           1         0              11
# 4 HAMBI_2659  8    16        1           1         0               1
# 5 HAMBI_3172  8    16        1           1         0               1
# 6 HAMBI_2659 12    16        1           1         0               1
#   REL_ABUNDANCE LOG_REL_ABUNDANCE
# 1 0             -13
# 2 0             -13
# 3 0             -13
# 4 0             -13
# 5 0             -13
# 6 0             -13

# %%
# Reformat

counts$SAMPLE = paste(counts$ANTIBIOTIC, 
                      counts$IMMIGRATION, 
                      counts$REPLICATE,
                      sep = "_")

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Data exploration

# %%
# Balance of categorical covariates

x = as.data.frame(table(counts$SPECIES))
x

# Let's remove species with less than 30 observations

y = x[x$Freq >= 30,]
y
counts2 = counts[counts$SPECIES %in% y$Var1,]

table(counts2$ANTIBIOTIC) # ok
table(counts2$IMMIGRATION) # ok
# Out:
#    Var1       Freq
# 1  HAMBI_105  32
# 2  HAMBI_1287 48
# 3  HAMBI_1874 34
# 4  HAMBI_1875 48
# 5  HAMBI_1896 46
# 6  HAMBI_1972 42
# 7  HAMBI_1977 40
# 8  HAMBI_1992  0
# 9  HAMBI_2160 12
# 10 HAMBI_2443 12
# 11 HAMBI_2659 14
# 12 HAMBI_3031 18
# 13 HAMBI_3172 36
#    Var1       Freq
# 1  HAMBI_105  32
# 2  HAMBI_1287 48
# 3  HAMBI_1874 34
# 4  HAMBI_1875 48
# 5  HAMBI_1896 46
# 6  HAMBI_1972 42
# 7  HAMBI_1977 40
# 13 HAMBI_3172 36
#   0   4  16 128
#  86  88  86  66
#   0   1
# 166 160

# %% [markdown]
# ## Model specification

# %%
# Let's use generalized least squares models that account for repeated measures

# Define basic model

M1 = gls(COUNT ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME + LOG_REL_ABUNDANCE, 
         data = counts2, 
         correlation = corAR1(form = ~ 1 | SAMPLE),
         method = "ML")

# Find best model based on AIC

M2 = stepAIC(M1, 
             scope = list(upper = ~SPECIES*ANTIBIOTIC*IMMIGRATION*TIME*LOG_REL_ABUNDANCE, lower = ~1), 
             trace = FALSE)

# %%
# Let's also try with species specific variance structure

M3 = gls(COUNT ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME + LOG_REL_ABUNDANCE, 
         data = counts2, 
         weights = varIdent(form = ~1 | SPECIES),
         correlation = corAR1(form = ~ 1 | SAMPLE),
         method = "ML")
M4 = stepAIC(M3, 
             scope = list(upper = ~SPECIES*ANTIBIOTIC*IMMIGRATION*TIME*LOG_REL_ABUNDANCE, lower = ~1), 
             trace = FALSE)

# %%
# Let's compare models with and without species specific variance structure

anova(M2, M4) # M4 better
# Out:
#    call
# M2 gls(model = COUNT ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME +     LOG_REL_ABUNDANCE + SPECIES:ANTIBIOTIC + SPECIES:IMMIGRATION +     ANTIBIOTIC:IMMIGRATION + SPECIES:ANTIBIOTIC:IMMIGRATION,     data = counts2, correlation = corAR1(form = ~1 | SAMPLE),     method = "ML")
# M4 gls(model = COUNT ~ SPECIES + ANTIBIOTIC + IMMIGRATION + TIME +     LOG_REL_ABUNDANCE + SPECIES:ANTIBIOTIC + SPECIES:LOG_REL_ABUNDANCE +     ANTIBIOTIC:LOG_REL_ABUNDANCE + SPECIES:TIME + SPECIES:IMMIGRATION +     TIME:LOG_REL_ABUNDANCE + IMMIGRATION:LOG_REL_ABUNDANCE +     SPECIES:ANTIBIOTIC:LOG_REL_ABUNDANCE, data = counts2, correlation = corAR1(form = ~1 |     SAMPLE), weights = varIdent(form = ~1 | SPECIES), method = "ML")
#    Model df AIC      BIC      logLik    Test   L.Ratio  p-value
# M2 1     36 2124.705 2261.034 -1026.353              NA           NA
# M4 2     59 1928.844 2152.271  -905.422 1 vs 2 241.8615 2.044759e-38

# %% [markdown]
# ## Model validation

# %%
# Homogeneity: residuals vs. predicted values

E1 = resid(M4)
F1 = fitted(M4)
par(mfrow = c(1, 1))
plot(x = F1, 
     y = E1, 
     xlab = "Fitted values",
     ylab = "Residuals")
abline(v = 0, lwd = 2, col = 2)
abline(h = 0, lty = 2, col = 1)
# Out:
# plot without title

# %%
# Homogeneity/independence: residuals vs. covariates

plot( x = counts2$SPECIES,
      y = E1,
      xlab = "Species",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$ANTIBIOTIC,
      y = E1,
      xlab = "Antibiotic",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$IMMIGRATION,
      y = E1,
      xlab = "Immigration",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$LOG_REL_ABUNDANCE,
      y = E1,
      xlab = "Relative abundance",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok

plot( x = counts2$TIME,
      y = E1,
      xlab = "Time",
      ylab = "Pearson residuals",
      cex.lab = 1.5)
abline(h = 0, lty = 2) # ok
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# Normality

par(mfrow = c(1, 1))
hist(E1, breaks = 10) # ok
# Out:
# Plot with title “Histogram of E1”

# %% [markdown]
# ## Model inspection

# %%
# Model validation plots look ok, let's go with M4

anova(M4)

# species, antibiotic, immigration and species abundance all explain total variant count
# also many interactions, the biggest being between species and antibiotic, and species and relative abundance
# Out:
#                                      numDF F-value    p-value
# (Intercept)                          1     595.177106  7.479343e-71
# SPECIES                              7     192.452692 2.859571e-102
# ANTIBIOTIC                           1     129.853649  6.542724e-25
# IMMIGRATION                          1       9.265539  2.560348e-03
# TIME                                 1       2.747942  9.851582e-02
# LOG_REL_ABUNDANCE                    1      94.540762  2.086122e-19
# SPECIES:ANTIBIOTIC                   7      51.711456  1.033972e-46
# SPECIES:LOG_REL_ABUNDANCE            7       3.587866  1.028411e-03
# ANTIBIOTIC:LOG_REL_ABUNDANCE         1      11.406821  8.370427e-04
# SPECIES:TIME                         7       1.870724  7.435614e-02
# SPECIES:IMMIGRATION                  7       3.156114  3.165871e-03
# TIME:LOG_REL_ABUNDANCE               1       5.468010  2.008184e-02
# IMMIGRATION:LOG_REL_ABUNDANCE        1       2.615051  1.069964e-01
# SPECIES:ANTIBIOTIC:LOG_REL_ABUNDANCE 7       3.010293  4.605422e-03

# %%
# Species effect

counts$SPECIES = as.factor(as.character(counts$SPECIES))

ggplot(counts, aes(SPECIES, COUNT)) +
    geom_boxplot() +
    ylab("Total number of mutations") +
    coord_flip() +
    scale_x_discrete(limits = rev(levels(counts$SPECIES))) +
    theme(axis.title.y = element_blank())

ggsave("../../manuscript/figures/count_analyses_all_variants_species.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
# Immigration effect

# Reformat

counts$IMMIGRATION = factor(counts$IMMIGRATION,
                           levels = c("0", "1"),
                           labels = c("No immigration", "Immigration"))

# %%
# Plot

ggplot(counts, aes(IMMIGRATION, COUNT)) +
    geom_boxplot() +
    ylab("Total number of mutations") +
    coord_flip() +
    scale_x_discrete(limits = rev(levels(counts$IMMIGRATION))) +
    theme(axis.title.y = element_blank())

ggsave("../../manuscript/figures/count_analyses_all_variants_immigration.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
# Antibiotic effect

ggplot(counts, aes(factor(ANTIBIOTIC), COUNT)) +
    geom_boxplot() +
    ylab("Total number of mutations") +
    coord_flip() +
    scale_x_discrete(limits = rev(levels(counts$ANTIBIOTIC))) +
    xlab(expression(paste("Streptomycin concentration ", (mu*g*' mL'^-1))))

ggsave("../../manuscript/figures/count_analyses_all_variants_antibiotic.pdf")
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
# Relative abundance by antibiotic effect

# Reformat

counts$ANTIBIOTIC = factor(counts$ANTIBIOTIC, 
                           levels = c("0", "4", "16", "128"),
                           labels = c(expression(paste(0~mu*g*' mL'^-1, " streptomycin")),
                                  expression(paste(4~mu*g*' mL'^-1, " streptomycin")),
                                  expression(paste(16~mu*g*' mL'^-1, " streptomycin")),
                                  expression(paste(128~mu*g*' mL'^-1, " streptomycin"))))

# %%
# Plot code

ggplot(counts, aes(REL_ABUNDANCE, COUNT))+
    geom_smooth(method = "glm", method.args = list(family = "poisson"),colour="red")+
    xlab("Relative species abundance (log10)")+
    ylab("Total number of mutations")+
    geom_point() +
    scale_x_log10() +
    facet_grid(~ANTIBIOTIC, scales="free", labeller = label_parsed)

ggsave("../../manuscript/figures/count_analyses_all_variants_abundance_by_antibiotic.pdf")
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”Warning message:
# “Transformation introduced infinite values in continuous x-axis”Warning message:
# “Removed 21 rows containing non-finite values (stat_smooth).”
# Saving 7 x 7 in image
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”Warning message:
# “Transformation introduced infinite values in continuous x-axis”Warning message:
# “Removed 21 rows containing non-finite values (stat_smooth).”
# plot without title
